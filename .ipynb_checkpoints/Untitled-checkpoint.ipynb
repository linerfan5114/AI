# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as p
from sklearn.preprocessing import scale
from sklearn.impute import SimpleImputer

df = pd.read_csv("house.csv")

df["Area"]=pd.to_numeric(df.Area,errors='coerce')
df.replace({True:1,False:0},inplace=True)
print(df)
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3474   86.0     2        1          1         1  Southern Janatabad
# 3475   83.0     2        1          1         1            Niavaran
# 3476   75.0     2        0          0         0              Parand
# 3477  105.0     2        1          1         1              Dorous
# 3478   82.0     2        0          1         1              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# ...

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3474   86.0     2        1          1         1  Southern Janatabad
# 3475   83.0     2        1          1         1            Niavaran
# 3476   75.0     2        0          0         0              Parand
# 3477  105.0     2        1          1         1              Dorous
# 3478   82.0     2        0          1         1              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# ...

# %%
print(df.dtypes)
# Out:
# Area          float64
# Room            int64
# Parking         int64
# Warehouse       int64
# Elevator        int64
# Address        object
# Price         float64
# Price(USD)    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Area           6
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %%
df.dropna
df
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3473   63.0     1        1          1         0         Feiz Garden
# 3474   86.0     2        1          1         1  Southern Janatabad
# 3475   83.0     2        1          1         1            Niavaran
# 3477  105.0     2        1          1         1              Dorous
# 3478   82.0     2        0          1         1              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# ...

# %%
df.shape
# Out:
# (3450, 8)

# %%
df.duplicated().sum()
# Out:
# np.int64(208)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3473   63.0     1        1          1         0         Feiz Garden
# 3474   86.0     2        1          1         1  Southern Janatabad
# 3475   83.0     2        1          1         1            Niavaran
# 3477  105.0     2        1          1         1              Dorous
# 3478   82.0     2        0          1         1              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# ...

# %%
df.reset_index(drop=True,inplace=True)
df.shape
# Out:
# (3242, 8)

# %%
p.hist(df["Price"], bins = "auto")
p.show()

# %%
import seaborn as sns
sns.lmplot(x="Area",y="Price",data=df,hue="Warehouse")
p.show()

# %%
address=set(df.Address)
Address={}
for i,j in enumerate(address,start=1):
    x={j:i}
    Address.update(x)
number_address=df.Address.map(lambda s:Address.get(s) if s in Address else s)
number_address
# Out:
# 0       134
# 1       134
# 2        54
# 3        23
# 4       135
#        ...
# 3237     82
# 3238     91
# 3239     98
# 3240    108
# 3241     57
# Name: Address, Length: 3242, dtype: int64

# %%
address=set(df.Address)
Address={}
for i in address:
    j=df[df['Address']==i].Price.sum()/df[df['Address']==i].Area.sum()
    x={i:j}
    Address.update(x)
average_price=df.Address.map(lambda s:Address.get(s) if s in Address else  s)
average_price
# Out:
# 0       3.668519e+07
# 1       3.668519e+07
# 2       8.204639e+06
# 3       1.000572e+07
# 4       8.625069e+07
#             ...
# 3237    3.738220e+07
# 3238    3.945778e+07
# 3239    1.106100e+08
# 3240    9.718675e+07
# 3241    6.521264e+06
# Name: Address, Length: 3242, dtype: float64

# %%
df.drop(df[(df['Area']>500.0) & (df['Room']<4)].index,axis=0,inplace=True)
df
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3237   63.0     1        1          1         0         Feiz Garden
# 3238   86.0     2        1          1         1  Southern Janatabad
# 3239   83.0     2        1          1         1            Niavaran
# 3240  105.0     2        1          1         1              Dorous
# 3241   82.0     2        0          1         1              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# ...

# %%
y=np.asarray(df['Price'])
y
# Out:
# array([1.85e+09, 1.85e+09, 5.50e+08, ..., 6.80e+09, 5.60e+09, 3.60e+08],
#       shape=(3233,))

# %%
for i in df.columns[6:]:
    df.drop(i,axis=1,inplace=True)
df
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3237   63.0     1        1          1         0         Feiz Garden
# 3238   86.0     2        1          1         1  Southern Janatabad
# 3239   83.0     2        1          1         1            Niavaran
# 3240  105.0     2        1          1         1              Dorous
# 3241   82.0     2        0          1         1              Parand
#
# [3233 rows x 6 columns]

# %%
# Out:
# 'porn'

# %%
#df.to_csv("newhouse.csv", index=False)
